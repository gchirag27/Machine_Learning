# %%
'''
Documentation:
Topic: Find relation between X and Y using TensorFlow (GSP637)
Dataset: X=[-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], Y=[-2.0, 1.0, 4.0, 7.0, 10.0, 13.0]
'''

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)
model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 761ms/step - loss: 22.1475
# Epoch 2/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 17.4416
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 13.7388
# Epoch 4/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 10.8254
# Epoch 5/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 8.5328
# Epoch 6/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7289
# Epoch 7/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3093
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1921
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3128
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6208
# Epoch 11/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0760
# Epoch 12/1000
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[31.000034]]

# %%
'''
As you look at them, you might notice that the value of X is increasing by 1 as you read left to right and the corresponding value of Y is increasing by 3. 
You probably think that Y equals 3X plus or minus something.
Then, you'd probably look at the 0 on X and see that Y is 1, and you'd come up with the relationship Y=3X+1.
You might have thought 31, but it ended up being a little over. Why do you think that is?
Neural networks deal with probabilities, so it calculated that there is a very high probability that the relationship between X and Y is Y=3X+1, but it can't know for sure with only six data points.
The result is very close to 31, but not necessarily 31.
As you work with neural networks, you'll see that pattern recurring. 
You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.
'''
